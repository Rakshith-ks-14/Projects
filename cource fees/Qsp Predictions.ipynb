# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pred=pd.read_excel('qsp_merged_df.xlsx')

# %%
pred.head()
# Out:
#       Candidate Name_x Gender Date of Birth Contact No_x  \
# 0     Shree harsha V K    NaN           NaN   9742872822
# 1          Hemanth N V    NaN           NaN   9886988075
# 2   M S Ramasubramanya   male    11-05-1993   7022021422
# 3  Satya prakash sahoo   male    26-06-1991   9090396977
# 4   Nikhil Chaturvedi     NaN           NaN   9098387116
#
#                       Email ID Fresher/Experienced 10th Board  10th YOP  \
# 0   shreeharsha.3042@gmail.com                 NaN        NaN       NaN
# 1  hemanth_babu_star@yahoo.com                 NaN        NaN       NaN
# 2  ramasubramanya123@gmail.com             Fresher       SSLC    2009.0
# 3     spsahoopro1990@gmail.com             Fresher       SSLC    2006.0
# 4       nikhilchat99@gmail.com                 NaN        NaN       NaN
#
#    10th % 12th Board  ... Contact No_y  Qualification Stream YOP 10th 12th  \
# 0     NaN        NaN  ...          NaN            NaN    NaN NaN  NaN  NaN
# ...

# %%
pd.set_option('display.max_rows',4000)
round(100*pred.isna().sum()/len(pred),2)
# Out:
# Candidate Name_x                        0.00
# Gender                                 48.99
# Date of Birth                          48.88
# Contact No_x                            0.06
# Email ID                                0.06
# Fresher/Experienced                    28.15
# 10th Board                             52.93
# 10th YOP                               53.23
# 10th %                                 53.32
# 12th Board                             53.31
# 12th Course Type                       56.76
# 12th/Diploma YOP                       53.34
# 12th %                                 53.38
# Diploma Course Type                    94.95
# Diploma Stream                         94.96
# Diploma University                     96.55
# Diploma College                        95.03
# Degree Course Type                     53.37
# Degree                                 50.12
# Degree Stream                          50.71
# Degree YOP                             50.17
# ...

# %%
# pred.info()

# %%
pred['Did You Have Backlogs in Degree?'].fillna(value='no',inplace=True)
pred["Have existing backlogs in Master's?"].fillna(value='no',inplace=True)
pred["Have year gap in Master's?"].fillna(value='no',inplace=True)

# %%
pred['Highest Qualification'].value_counts()
# Out:
# BE         618
# MCA         45
# BTech       28
# M.Tech      21
# BCA         18
# MSC         16
# MBA         14
# BSC         10
# M.S.         5
# M.E          3
# BCOM         3
# BBM          1
# Diploma      1
# gfdg         1
# M Com        1
# BHM          1
# ML           1
# Name: Highest Qualification, dtype: int64

# %%
pd.set_option('display.max_rows',4000)
pred[["Master's","Master's Stream","Master's Degree Course Type","Master's %","Master's YOP"]]
# Out:
#      Master's   Master's Stream Master's Degree Course Type Master's %  \
# 0         NaN               NaN                         NaN        NaN
# 1         NaN               NaN                         NaN        NaN
# 2         NaN               NaN                         NaN        NaN
# 3         MCA  Computer Science                     Regular     72.00%
# 4         NaN               NaN                         NaN        NaN
# ...       ...               ...                         ...        ...
# 8129      NaN               NaN                         NaN        NaN
# 8130      NaN               NaN                         NaN        NaN
# 8131      NaN               NaN                         NaN        NaN
# 8132      NaN               NaN                         NaN        NaN
# 8133      NaN               NaN                         NaN        NaN
#
#       Master's YOP
# 0              NaN
# 1              NaN
# 2              NaN
# 3           2015.0
# ...

# %%
for i,j in zip(pred['Highest Qualification'],pred['Degree Stream']):
    if i=='NaN' and j!='NaN':
        i='BE'

# %%
pred['Degree Stream'].isna()
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8129     True
# 8130    False
# 8131     True
# 8132     True
# 8133    False
# Name: Degree Stream, Length: 8134, dtype: bool

# %%
pred[(pred['Highest Qualification'].isna()==True) & (pred['Degree Stream'].isna()!=True)]['Highest Qualification']
# Out:
# 2       NaN
# 3       NaN
# 6       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 14      NaN
# 15      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN
# 40      NaN
# 41      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# 49      NaN
# 50      NaN
# 51      NaN
# 52      NaN
# 54      NaN
# 56      NaN
# 59      NaN
# 65      NaN
# 66      NaN
# 68      NaN
# 71      NaN
# 74      NaN
# 76      NaN
# 77      NaN
# 80      NaN
# 81      NaN
# 82      NaN
# 83      NaN
# 85      NaN
# 86      NaN
# 87      NaN
# 89      NaN
# 91      NaN
# 98      NaN
# 99      NaN
# 100     NaN
# 101     NaN
# 109     NaN
# 113     NaN
# 114     NaN
# 117     NaN
# 118     NaN
# 119     NaN
# 120     NaN
# 121     NaN
# 122     NaN
# 123     NaN
# 130     NaN
# 138     NaN
# 143     NaN
# 147     NaN
# ...

# %%
pred['Highest Qualification'].fillna("Not_Mentioned",inplace=True)

# %%
pred['Degree'].fillna("Not_Mentioned",inplace=True)

# %%
pred['Highest Qualification']=pred.apply(lambda x: x['Degree'] if x['Highest Qualification']=="Not_Mentioned" and x['Degree']!="Not_Mentioned" else x['Highest Qualification'],axis=1)

# %%
pred['Highest Qualification'].value_counts()
# Out:
# Not_Mentioned    3724
# BE               3054
# BTech             631
# BCA               349
# BSC               201
# MCA                47
# BCOM               29
# M.Tech             21
# MSC                17
# MBA                14
# BBM                 7
# ABC                 6
# M.S.                5
# BA                  4
# abc                 3
# M.TECH              3
# M.E                 3
# abcd                3
# Diplamo             2
# Abc                 2
# BHM                 1
# ABCD                1
# BSCAG               1
# gfdg                1
# ML                  1
# BBA                 1
# m.tech              1
# Diploma             1
# M Com               1
# Name: Highest Qualification, dtype: int64

# %%
pred['Degree University'].isnull()
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8129     True
# 8130     True
# 8131     True
# 8132     True
# 8133    False
# Name: Degree University, Length: 8134, dtype: bool

# %%
pred['Degree']=pred.apply(lambda x: x['Degree'] if pd.isnull(x["Master's"]) else x["Master's"], axis=1)

# %%
pred['Degree Stream']=pred.apply(lambda x: x['Degree Stream'] if pd.isnull(x["Master's Stream"]) else x["Master's Stream"], axis=1)

# %%
pred['Degree YOP']=pred.apply(lambda x: x['Degree YOP'] if pd.isnull(x["Master's YOP"]) else x["Master's YOP"], axis=1)

# %%
pred['Degree %_x']=pred.apply(lambda x: x['Degree %_x'] if pd.isnull(x["Master's %"]) else x["Master's %"], axis=1)
